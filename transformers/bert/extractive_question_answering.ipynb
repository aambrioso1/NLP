# %% [markdown]
# # Using Transformers for Question Answering
#
# BERT:  https://huggingface.co/transformers/model_doc/bert.html
#
# Example using Bert for question answering.  Found here:
# https://huggingface.co/transformers/task_summary.html#extractive-question-answering
#
# Need to study this script for fine-tuning the transformers library models for question answering:
# https://github.com/huggingface/transformers/blob/master/examples/pytorch/question-answering/run_qa.py
#
# **Things to Do**
# I want to run BERT on a small set of the paragraphs and question in in SQuAD 2.0 to get a sense of what the files look like.

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
import torch

# Here we use a Bert model that has been fine-tuned.
tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")
model = AutoModelForQuestionAnswering.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")

# The text is from the Wikipedia article on Austen's last novel Persuasion.
# https://en.wikipedia.org/wiki/Persuasion_(novel)

text = r"""BERT has its origins from pre-training contextual representations\
including Semi-supervised Sequence Learning,[12] Generative Pre-Training, ELMo\
,[13] and ULMFit.[14] Unlike previous models, BERT is a deeply bidirectional,\
unsupervised language representation, pre-trained using only a plain text corpus.\
Context-free models such as word2vec or GloVe generate a single word embedding \
representation for each word in the vocabulary, where BERT takes into account the \
context for each occurrence of a given word. For instance, whereas the vector for 
"running" will have the same word2vec vector representation for both of its \
occurrences in the sentences "He is running a company" and "He is running a marathon"\
, BERT will provide a contextualized embedding that will be different according\
to the sentence.
"""

questions = ['What is Bert?',\
             'How is BERT pre-trained?',\
             'WHat does BERT take into account?',\
             'Who is Ernie?',\
            ]

n = 50 # number of asterisks printed for a frame around the results
print(n * '*')
for question in questions:
    inputs = tokenizer(question, text, add_special_tokens=True, return_tensors="pt")
    input_ids = inputs["input_ids"].tolist()[0]
    outputs = model(**inputs)
    answer_start_scores = outputs.start_logits
    answer_end_scores = outputs.end_logits

    # pick location of most probable answers
    answer_start = torch.argmax(answer_start_scores)  # Get the most likely beginning of answer with the argmax of the score
    answer_end = torch.argmax(answer_end_scores) + 1  # Get the most likely end of answer with the argmax of the score
    
    # converts answer from tokens to strings
    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(input_ids[answer_start:answer_end]))
    
    
    print(f"Question: {question}")
    print(f"Answer: {answer}")
    print(n * '*')
# Out:
# **************************************************
# Question: What is Bert?
# Answer: a deeply bidirectional, \ unsupervised language representation
# **************************************************
# Question: How is BERT pre-trained?
# Answer: using only a plain text corpus
# **************************************************
# Question: WHat does BERT take into account?
# Answer: context for each occurrence of a given word
# **************************************************
# Question: Who is Ernie?
# Answer: elmo
# **************************************************

# %% [markdown]
# The follow code follows a portion of the run_squad.py file found here:
#
# https://github.com/google-research/bert
#
# README for BERT files maintained by the creators of BERT.
#
# https://github.com/google-research/bert/blob/master/README.md
#
# The code was written by the creators of BERT.

# %%
import json

path = "C:\\Users\\Alex\\nlp\\pytorch\\data_sets\\SQuAD\\train-v2.0.json"


# Similar to code found around line 227 or run_squad.py

# Load json file for SQuAD 2.0
with open(path, 'r') as reader:
    data = json.loads(reader.read())['data']
    print(len(data))

# print paragraphs and questions from SQuAD dataset
for i, entry in enumerate(data):
    for j, paragraph in enumerate(entry['paragraphs']):
        print(f'*** Paragraph {j+1} ***')
        paragraph_text = paragraph['context']
        print(f'\nparagraph_text = {paragraph_text}\n')
        for qa in paragraph['qas']:
            question_text = qa['question']
            print(f'question_text = {question_text}')
        print(10 * '*')
        number_of_paragraphs = 5
        if j >= (number_of_paragraphs - 1):
            break
# Out:
# 442
# *** Paragraph 1 ***
#
# paragraph_text = Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
#
# question_text = When did Beyonce start becoming popular?
# question_text = What areas did Beyonce compete in when she was growing up?
# question_text = When did Beyonce leave Destiny's Child and become a solo singer?
# question_text = In what city and state did Beyonce  grow up?
# question_text = In which decade did Beyonce become famous?
# question_text = In what R&B group was she the lead singer?
# question_text = What album made her a worldwide known artist?
# question_text = Who managed the Destiny's Child group?
# question_text = When did Beyoncé rise to fame?
# question_text = What role did Beyoncé have in Destiny's Child?
# question_text = What was the first album Beyoncé released as a solo artist?
# question_text = When did Beyoncé release Dangerously in Love?
# question_text = How many Grammy awards did Beyoncé win for her first solo album?
# question_text = What was Beyoncé's role in Destiny's Child?
# question_text = What was the name of Beyoncé's first solo album?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplaceable", and "Beautiful Liar". Beyoncé also ventured into acting, with a Golden Globe-nominated performance in Dreamgirls (2006), and starring roles in The Pink Panther (2006) and Obsessed (2009). Her marriage to rapper Jay Z and portrayal of Etta James in Cadillac Records (2008) influenced her third album, I Am... Sasha Fierce (2008), which saw the birth of her alter-ego Sasha Fierce and earned a record-setting six Grammy Awards in 2010, including Song of the Year for "Single Ladies (Put a Ring on It)". Beyoncé took a hiatus from music in 2010 and took over management of her career; her fourth album 4 (2011) was subsequently mellower in tone, exploring 1970s funk, 1980s pop, and 1990s soul. Her critically acclaimed fifth studio album, Beyoncé (2013), was distinguished from previous releases by its experimental production and exploration of darker themes.
#
# question_text = After her second solo album, what other entertainment venture did Beyonce explore?
# question_text = Which artist did Beyonce marry?
# question_text = To set the record for Grammys, how many did Beyonce win?
# question_text = For what movie did Beyonce receive  her first Golden Globe nomination?
# question_text = When did Beyonce take a hiatus in her career and take control of her management?
# question_text = Which album was darker in tone from her previous work?
# question_text = After what movie portraying Etta James, did Beyonce create Sasha Fierce?
# question_text = When did Destiny's Child end their group act?
# question_text = What was the name of Beyoncé's second solo album?
# question_text = What was Beyoncé's first acting job, in 2006?
# question_text = Who is Beyoncé married to?
# question_text = What is the name of Beyoncé's alter-ego?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as female sexuality and empowerment. On stage, her dynamic, highly choreographed performances have led to critics hailing her as one of the best entertainers in contemporary popular music. Throughout a career spanning 19 years, she has sold over 118 million records as a solo artist, and a further 60 million with Destiny's Child, making her one of the best-selling music artists of all time. She has won 20 Grammy Awards and is the most nominated woman in the award's history. The Recording Industry Association of America recognized her as the Top Certified Artist in America during the 2000s decade. In 2009, Billboard named her the Top Radio Songs Artist of the Decade, the Top Female Artist of the 2000s and their Artist of the Millennium in 2011. Time listed her among the 100 most influential people in the world in 2013 and 2014. Forbes magazine also listed her as the most powerful female musician of 2015.
#
# question_text = In her music, what are some recurring elements in them?
# question_text = Time magazine named her one of the most 100 what people of the century?
# question_text = Which magazine declared her the most dominant woman musician?
# question_text = In which decade did the Recording Industry Association of America recognize Beyonce as the The Top Certified Artist?
# question_text = What magazine rated Beyonce as the most powerful female musician in 2015?
# question_text = How did Beyonce describe herself as a feminist?
# question_text = In which years did Time rate Beyonce in the 100 most influential people in the world?
# question_text = How many records has Beyonce sold in her 19 year career?
# question_text = How many records did Beyoncé sell as part of Destiny's Child?
# question_text = After leaving Destiny's Child, how many records did Beyoncé release under her own name?
# question_text = How many Grammy awards has Beyoncé won?
# question_text = What magazine named Beyoncé as the most powerful female musician for 2015?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, a Xerox sales manager. Beyoncé's name is a tribute to her mother's maiden name. Beyoncé's younger sister Solange is also a singer and a former member of Destiny's Child. Mathew is African-American, while Tina is of Louisiana Creole descent (with African, Native American, French, Cajun, and distant Irish and Spanish ancestry). Through her mother, Beyoncé is a descendant of Acadian leader Joseph Broussard. She was raised in a Methodist household.
#
# question_text = Beyonce's younger sibling also sang with her in what band?
# question_text = Where did Beyonce get her name from?
# question_text = What race was Beyonce's father?
# question_text = Beyonce's childhood home believed in what religion?
# question_text = Beyonce's father worked as a sales manager for what company?
# question_text = Beyonce's mother worked in what industry?
# question_text = What younger sister of Beyonce also appeared in Destiny's Child?
# question_text = Beyonce is a descendent of what Arcadian leader?
# question_text = What company did Beyoncé's father work for when she was a child?
# question_text = What did Beyoncé's mother own when Beyoncé was a child?
# question_text = What is the name of Beyoncé's younger sister?
# question_text = Beyoncé is a descendant of which Acadian leader?
# question_text = Beyoncé was raised in what religion?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = Beyoncé attended St. Mary's Elementary School in Fredericksburg, Texas, where she enrolled in dance classes. Her singing talent was discovered when dance instructor Darlette Johnson began humming a song and she finished it, able to hit the high-pitched notes. Beyoncé's interest in music and performing continued after winning a school talent show at age seven, singing John Lennon's "Imagine" to beat 15/16-year-olds. In fall of 1990, Beyoncé enrolled in Parker Elementary School, a music magnet school in Houston, where she would perform with the school's choir. She also attended the High School for the Performing and Visual Arts and later Alief Elsik High School. Beyoncé was also a member of the choir at St. John's United Methodist Church as a soloist for two years.
#
# question_text = What town did Beyonce go to school in?
# question_text = Who was the first person to notice Beyonce's singing ability?
# question_text = Beyonce moved to which town after she left her first elementary school?
# question_text = Which of her teachers discovered Beyonce's musical talent?
# question_text = I which church was Beyonce  a member and soloist  in the choir?
# question_text = What type of school was Parker Elementary School?
# question_text = Which song did Beyonce sing to win a competition at age 7?
# question_text = What city was Beyoncé's elementary school located in?
# question_text = What was the name of Beyoncé's first dance instructor?
# question_text = How old was Beyoncé when she won a school talent show?
# question_text = What choir did Beyoncé sing in for two years?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = Frédéric François Chopin (/ˈʃoʊpæn/; French pronunciation: ​[fʁe.de.ʁik fʁɑ̃.swa ʃɔ.pɛ̃]; 22 February or 1 March 1810 – 17 October 1849), born Fryderyk Franciszek Chopin,[n 1] was a Polish and French (by citizenship and birth of father) composer and a virtuoso pianist of the Romantic era, who wrote primarily for the solo piano. He gained and has maintained renown worldwide as one of the leading musicians of his era, whose "poetic genius was based on a professional technique that was without equal in his generation." Chopin was born in what was then the Duchy of Warsaw, and grew up in Warsaw, which after 1815 became part of Congress Poland. A child prodigy, he completed his musical education and composed his earlier works in Warsaw before leaving Poland at the age of 20, less than a month before the outbreak of the November 1830 Uprising.
#
# question_text = What was Frédéric's nationalities?
# question_text = In what era was Frédéric active in?
# question_text = For what instrument did Frédéric write primarily for?
# question_text = In what area was Frédéric born in?
# question_text = At what age did Frédéric depart from Poland?
# question_text = What year was Chopin born?
# question_text = What era was Chopin active during?
# question_text = Where did Chopin grow up?
# question_text = What instrument did he mostly compose for?
# question_text = At what age did Chopin  leave Poland?
# question_text = When did Chopin die?
# question_text = What was Chopin's full name?
# question_text = The majority of Chopin's compositions were for what instrument?
# question_text = Chopin was active during what era?
# question_text = In what year was Chopin born?
# question_text = In what city was Chopin born and raised?
# question_text = How old was Chopin when he left Poland?
# question_text = In what era of music did Chopin compose?
# question_text = What year did Chopin die?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = At the age of 21 he settled in Paris. Thereafter, during the last 18 years of his life, he gave only some 30 public performances, preferring the more intimate atmosphere of the salon. He supported himself by selling his compositions and teaching piano, for which he was in high demand. Chopin formed a friendship with Franz Liszt and was admired by many of his musical contemporaries, including Robert Schumann. In 1835 he obtained French citizenship. After a failed engagement to Maria Wodzińska, from 1837 to 1847 he maintained an often troubled relationship with the French writer George Sand. A brief and unhappy visit to Majorca with Sand in 1838–39 was one of his most productive periods of composition. In his last years, he was financially supported by his admirer Jane Stirling, who also arranged for him to visit Scotland in 1848. Through most of his life, Chopin suffered from poor health. He died in Paris in 1849, probably of tuberculosis.
#
# question_text = At what age did Frédéric move to Paris?
# question_text = How many public performances was Frédéric estimated to have given during the remainder of his life?
# question_text = In what year did Frédéric obtain citizenship in France?
# question_text = In what area had Frédéric's most productive period of composition taken place?
# question_text = What was Frédéric's most likely cause of death?
# question_text = Where did he end up living when he was 21?
# question_text = How many public shows did he perform during the last years of his life?
# question_text = What other composer did Chopin develop a friendship with?
# question_text = What year did he gain citizenship in France?
# question_text = What is the name of the woman he had a relationship with from 1837-847?
# question_text = At what age did Chopin move to Paris?
# question_text = During the last 18 years he lived about how many times did Chopin perform in public?
# question_text = What year did Chopin become a citizen of France?
# question_text = In the last years of his life who was the person that supported him financially?
# question_text = In what year did Chopin become a French citizen?
# question_text = Who gave Chopin money in the last years of his life?
# question_text = What was the likely cause of death for Chopin?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = All of Chopin's compositions include the piano. Most are for solo piano, though he also wrote two piano concertos, a few chamber pieces, and some songs to Polish lyrics. His keyboard style is highly individual and often technically demanding; his own performances were noted for their nuance and sensitivity. Chopin invented the concept of instrumental ballade. His major piano works also include mazurkas, waltzes, nocturnes, polonaises, études, impromptus, scherzos, preludes and sonatas, some published only after his death. Influences on his compositional style include Polish folk music, the classical tradition of J. S. Bach, Mozart and Schubert, the music of all of whom he admired, as well as the Paris salons where he was a frequent guest. His innovations in style, musical form, and harmony, and his association of music with nationalism, were influential throughout and after the late Romantic period.
#
# question_text = What instrument did every composition by Frédéric include?
# question_text = What concept was Frédéric credited with creating?
# question_text = Whose music did Frédéric admire the most and thus provide influence on his work?
# question_text = What features marked Frédéric's performance style and made them unique?
# question_text = What establishments did Frédéric frequently visit in Paris that influenced his career?
# question_text = Which instrument do every one of his compositions include?
# question_text = What concept did Chopin create?
# question_text = What are two things Chopin's performances were known for?
# question_text = What three composers influenced Chopin's work?
# question_text = Chopin wrote some music to lyrics, what language were the lyrics?
# question_text = What instrument is involved in all of Chopin's work?
# question_text = Chopin composed several songs to lyrics of what language?
# question_text = Chopin's performances were known for what?
# question_text = What three composers did Chopin take inspiration from?
# question_text = What instrument was all of Chopin's compositions written for?
# question_text = What language were some songs written in that Chopin wrote music for?
# question_text = Of what venue was Chopin an often invited guest?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = In his native Poland, in France, where he composed most of his works, and beyond, Chopin's music, his status as one of music's earliest superstars, his association (if only indirect) with political insurrection, his love life and his early death have made him, in the public consciousness, a leading symbol of the Romantic era. His works remain popular, and he has been the subject of numerous films and biographies of varying degrees of historical accuracy.
#
# question_text = What was the degree of Frédéric's association with political insurrection?
# question_text = What parts of Frédéric's personal life influenced his legacy as a leading symbol of the era?
# question_text = In which era was Frédéric leave a legacy of as a leading symbol?
# question_text = In what forms of media has Frédéric been the subject of?
# question_text = Where did Chopin create the majority of his compositions?
# question_text = Chopin is a native of what country?
# question_text = He had a non-direct association with what?
# question_text = Chopin is closely associated with what era?
# question_text = Where did Chopin create most of his works?
# question_text = Chopin was indirectly related to what?
# question_text = Chopin is considered a prominent symbol of what?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = Fryderyk Chopin was born in Żelazowa Wola, 46 kilometres (29 miles) west of Warsaw, in what was then the Duchy of Warsaw, a Polish state established by Napoleon. The parish baptismal record gives his birthday as 22 February 1810, and cites his given names in the Latin form Fridericus Franciscus (in Polish, he was Fryderyk Franciszek). However, the composer and his family used the birthdate 1 March,[n 2] which is now generally accepted as the correct date.
#
# question_text = In what village was Frédéric born in?
# question_text = On what date was Frédéric born on?
# question_text = Despite the birthdate given by parish baptismal, what date is given by the composer and his family instead?
# question_text = What was the latin form of Frédéric's full name?
# question_text = How many miles was the village Frédéric born in located to the west of Warsaw?
# question_text = Where was Chopin born?
# question_text = Who was responsible for the creation of the Duchy of Warsaw?
# question_text = When was his birthday recorded as being?
# question_text = What birth date is now considered as his actual birthday?
# question_text = Chopin's given names in Latin are what?
# question_text = The Duchy of Warsaw was created by whom?
# question_text = Chopin's birth is recorded as when?
# question_text = What birth date is now considered correct for Chopin?
# question_text = What is the Latin form of Chopin's name?
# question_text = Chopin was actually born outside of Warsaw at what location?
# question_text = What famous French leader had established the Polish state at this time?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = The exact nature of relations between Tibet and the Ming dynasty of China (1368–1644) is unclear. Analysis of the relationship is further complicated by modern political conflicts and the application of Westphalian sovereignty to a time when the concept did not exist. Some Mainland Chinese scholars, such as Wang Jiawei and Nyima Gyaincain, assert that the Ming dynasty had unquestioned sovereignty over Tibet, pointing to the Ming court's issuing of various titles to Tibetan leaders, Tibetans' full acceptance of these titles, and a renewal process for successors of these titles that involved traveling to the Ming capital. Scholars within China also argue that Tibet has been an integral part of China since the 13th century and that it was thus a part of the Ming Empire. But most scholars outside China, such as Turrell V. Wylie, Melvin C. Goldstein, and Helmut Hoffman, say that the relationship was one of suzerainty, that Ming titles were only nominal, that Tibet remained an independent region outside Ming control, and that it simply paid tribute until the Jiajing Emperor (1521–1566), who ceased relations with Tibet.
#
# question_text = Who were Wang Jiawei and Nyima Gyaincain?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = Some scholars note that Tibetan leaders during the Ming frequently engaged in civil war and conducted their own foreign diplomacy with neighboring states such as Nepal. Some scholars underscore the commercial aspect of the Ming-Tibetan relationship, noting the Ming dynasty's shortage of horses for warfare and thus the importance of the horse trade with Tibet. Others argue that the significant religious nature of the relationship of the Ming court with Tibetan lamas is underrepresented in modern scholarship. In hopes of reviving the unique relationship of the earlier Mongol leader Kublai Khan (r. 1260–1294) and his spiritual superior Drogön Chögyal Phagpa (1235–1280) of the Sakya school of Tibetan Buddhism, the Yongle Emperor (r. 1402–1424) made a concerted effort to build a secular and religious alliance with Deshin Shekpa (1384–1415), the Karmapa of the Karma Kagyu school. However, the Yongle Emperor's attempts were unsuccessful.
#
# question_text = What important trade did the Ming Dynasty have with Tibet?
# question_text = During what years did the Mongol leader Kublai Khan rule?
# question_text = Who did the Yongle Emperor try to build a religious alliance with?
# question_text = Deshin Shekpa was the head of what school?
# question_text = The Tibetan leaders had a diplomacy with what neighboring state?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = The Ming initiated sporadic armed intervention in Tibet during the 14th century, but did not garrison permanent troops there. At times the Tibetans also used armed resistance against Ming forays. The Wanli Emperor (r. 1572–1620) made attempts to reestablish Sino-Tibetan relations after the Mongol-Tibetan alliance initiated in 1578, which affected the foreign policy of the subsequent Qing dynasty (1644–1912) of China in their support for the Dalai Lama of the Gelug school. By the late 16th century, the Mongols were successful armed protectors of the Gelug Dalai Lama, after increasing their presence in the Amdo region. This culminated in Güshi Khan's (1582–1655) conquest of Tibet from 1637–1642 and the establishment of the Ganden Phodrang regime by the 5th Dalai Lama with his help.
#
# question_text = What did the Tibetans use against Ming forays?
# question_text = Who were the armed protectors for the Gelug Dalai Lama?
# question_text = Which regime did Güshi Khan help establish?
# question_text = When was the Mongol-Tibetan alliance started?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = Tibet was once a strong power contemporaneous with Tang China (618–907). Until the Tibetan Empire's collapse in the 9th century, it was the Tang's major rival in dominating Inner Asia. The Yarlung rulers of Tibet also signed various peace treaties with the Tang, culminating in a treaty in 821 that fixed the borders between Tibet and China.
#
# question_text = In what century did the Tibetan Empire fall?
# question_text = Who signed multiple peace treaties with the Tang?
# question_text = What did one of the treaties between the Tang and Tibet help fix?
# question_text = Who was the Tangs biggest rival?
# question_text = What year did Tang and Tibet sign a treaty to fix the borders?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = During the Five Dynasties and Ten Kingdoms period of China (907–960), while the fractured political realm of China saw no threat in a Tibet which was in just as much political disarray, there was little in the way of Sino-Tibetan relations. Few documents involving Sino-Tibetan contacts survive from the Song dynasty (960–1279). The Song were far more concerned with countering northern enemy states of the Khitan-ruled Liao dynasty (907–1125) and Jurchen-ruled Jin dynasty (1115–1234).
#
# question_text = When did the Five Dynasties and Ten Kingdoms period of China take place?
# question_text = When did the Song dynasty take place?
# question_text = What dynasty was concerned with countering northern enemy states?
# question_text = Who ruled the Liao dynasty?
# question_text = Who ruled the  Jin dynasty?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = The iPod is a line of portable media players and multi-purpose pocket computers designed and marketed by Apple Inc. The first line was released on October 23, 2001, about 8½ months after iTunes (Macintosh version) was released. The most recent iPod redesigns were announced on July 15, 2015. There are three current versions of the iPod: the ultra-compact iPod Shuffle, the compact iPod Nano and the touchscreen iPod Touch.
#
# question_text = Which company produces the iPod?
# question_text = When was the original iPod released?
# question_text = How many different types of iPod are currently available?
# question_text = What kind of device is the iPod?
# question_text = The iPod Touch uses what kind of interface?
# question_text = In what year was the first iPod released?
# question_text = What company manufactures the iPod?
# question_text = How many versions of the iPod currently exist?
# question_text = Which is the smallest version of the iPod?
# question_text = In what year was the iPod most recently redesigned?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = Like other digital music players, iPods can serve as external data storage devices. Storage capacity varies by model, ranging from 2 GB for the iPod Shuffle to 128 GB for the iPod Touch (previously 160 GB for the iPod Classic, which is now discontinued).
#
# question_text = In addition to playing music, what other function can the iPod perform?
# question_text = What is the smallest data capacity for an iPod product?
# question_text = What is the largest data capacity for an iPod product?
# question_text = Which iPod product features the smallest data storage capacity?
# question_text = Which current iPod product features the largest data storage capacity?
# question_text = What's the storage capacity of the iPod Shuffle?
# question_text = What's the storage capacity for the iPod Touch?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = Apple's iTunes software (and other alternative software) can be used to transfer music, photos, videos, games, contact information, e-mail settings, Web bookmarks, and calendars, to the devices supporting these features from computers using certain versions of Apple Macintosh and Microsoft Windows operating systems.
#
# question_text = What Apple program is used to communicate between computers and portable devices?
# question_text = Which operating systems are compatible with iTunes?
# question_text = What's the name of the software used to manage music and other media on Apple devices?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = Before the release of iOS 5, the iPod branding was used for the media player included with the iPhone and iPad, a combination of the Music and Videos apps on the iPod Touch. As of iOS 5, separate apps named "Music" and "Videos" are standardized across all iOS-powered products. While the iPhone and iPad have essentially the same media player capabilities as the iPod line, they are generally treated as separate products. During the middle of 2010, iPhone sales overtook those of the iPod.
#
# question_text = Prior to iOS 5, how many apps were required to play music and videos on iPhone and iPad?
# question_text = In mid-2010, which Apple device had higher sales than iPod?
# question_text = With what iOS release did Apple standardize media apps on all their products?
# question_text = In what year did iPhone sales surpass those of iPods?
# question_text = What are the titles of the standard media apps on current Apple devices?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = In mid-2015, a new model of the iPod Touch was announced by Apple, and was officially released on the Apple store on July 15, 2015. The sixth generation iPod Touch includes a wide variety of spec improvements such as the upgraded A8 processor and higher-quality screen. The core is over 5 times faster than previous models and is built to be roughly on par with the iPhone 5S. It is available in 5 different colors: Space grey, pink, gold, silver and Product (red).
#
# question_text = What processor model is used in the iPod Touch?
# question_text = Which generation of iPod Touch was made availalbe in July of 2015?
# question_text = What's the most recent generation of iPod Touch?
# question_text = In what year was the most recent iPod Touch released?
# question_text = What type of processor does the current iPod Touch use?
# question_text = In how many colors is the current iPod Touch available?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = The Legend of Zelda: Twilight Princess (Japanese: ゼルダの伝説 トワイライトプリンセス, Hepburn: Zeruda no Densetsu: Towairaito Purinsesu?) is an action-adventure game developed and published by Nintendo for the GameCube and Wii home video game consoles. It is the thirteenth installment in the The Legend of Zelda series. Originally planned for release on the GameCube in November 2005, Twilight Princess was delayed by Nintendo to allow its developers to refine the game, add more content, and port it to the Wii. The Wii version was released alongside the console in North America in November 2006, and in Japan, Europe, and Australia the following month. The GameCube version was released worldwide in December 2006.[b]
#
# question_text = What category of game is Legend of Zelda: Twilight Princess?
# question_text = What consoles can be used to play Twilight Princess?
# question_text = When was Twilight Princess launched in North America?
# question_text = When could GameCube owners purchase Twilight Princess?
# question_text = What company developed Legend of Zelda: Twilight Princess?
# question_text = What year was the Legend of Zelda:Twilight Princess originally planned for release?
# question_text = What year was the Wii version of Legend of Zelda: Twilight Princess released?
# question_text = What category of game is Legend of Zelda: Australia Twilight?
# question_text = What consoles can be used to play Australia Twilight?
# question_text = When was Australia Twilight launched in North America?
# question_text = When could GameCube owners purchase Australian Princess?
# question_text = What year was the Legend of Zelda: Australian Princess originally planned for release?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = The story focuses on series protagonist Link, who tries to prevent Hyrule from being engulfed by a corrupted parallel dimension known as the Twilight Realm. To do so, he takes the form of both a Hylian and a wolf, and is assisted by a mysterious creature named Midna. The game takes place hundreds of years after Ocarina of Time and Majora's Mask, in an alternate timeline from The Wind Waker.
#
# question_text = Who is the main character of the story?
# question_text = What land does Link serve to protect?
# question_text = What character helped Link in Twilight Princess?
# question_text = Who is the protagonist is Legend of Zelda?
# question_text = What is the name of the mysterious creature that assists Link?
# question_text = This storyline takes place alternate from what storyline?
# question_text = What land does Ocarina serve to protect?
# question_text = What character helped Link in Ocarina Princess?
# question_text = Who is the protagonist of Midna of Time?
# question_text = From what alternate dimension does this dimension take place from?
# question_text = When does the Waker take place?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = At the time of its release, Twilight Princess was considered the greatest entry in the Zelda series by many critics, including writers for 1UP.com, Computer and Video Games, Electronic Gaming Monthly, Game Informer, GamesRadar, IGN, and The Washington Post. It received several Game of the Year awards, and was the most critically acclaimed game of 2006. In 2011, the Wii version was rereleased under the Nintendo Selects label. A high-definition port for the Wii U, The Legend of Zelda: Twilight Princess HD, will be released in March 2016.
#
# question_text = What accolade did Twilight Princess receive after its release?
# question_text = Under which brand was Twilight Princess for the Nintendo Wii published?
# question_text = When is the HD version of Twilight Princess slated for launch?
# question_text = At the time of release which episode of the Legend of Zelda series was considered the greatest entry?
# question_text = How many Game of the Year awards did Twilight Princess receive?
# question_text = What year was Twilight Princess the most critically acclaimed game?
# question_text = What year will the game release a high-definition port for the Wii U console?
# question_text = What accolade did Radar Princess receive after its release?
# question_text = Under which brand was Radar Princess for the Nintendo Wii published?
# question_text = When is the HD version of Radar Princess slated for launch?
# question_text = At the time of release what episode of Legend of Radar series was considered the greatest story?
# question_text = How many Game of the Year awards did Radar Princess receive?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = The Legend of Zelda: Twilight Princess is an action-adventure game focused on combat, exploration, and item collection. It uses the basic control scheme introduced in Ocarina of Time, including context-sensitive action buttons and L-targeting (Z-targeting on the Wii), a system that allows the player to keep Link's view focused on an enemy or important object while moving and attacking. Link can walk, run, and attack, and will automatically jump when running off of or reaching for a ledge.[c] Link uses a sword and shield in combat, complemented with secondary weapons and items, including a bow and arrows, a boomerang, bombs, and the Clawshot (similar to the Hookshot introduced earlier in the The Legend of Zelda series).[d] While L-targeting, projectile-based weapons can be fired at a target without the need for manual aiming.[c]
#
# question_text = What are the three main activities in The Legend of Zelda: Twilight Princess?
# question_text = Twilight Princess uses the control setup first employed in which previous game?
# question_text = What can be used to shoot without the need to manually target enemies?
# question_text = What is Link's main weapon?
# question_text = What secondary weapon in Twilight Princess is analogous to a weapon featured in previous games?
# question_text = What genre of game is Twilight Princess?
# question_text = Twilight Princess follows the control scheme introduced in what game?
# question_text = What 2 main weapons does Link use in combat?
# question_text = What control can be used while targeting that allows the player to forego manual targeting?
# question_text = What are the three main activities in The Legend of Zelda: Clawshot Princess?
# question_text = Clawshot Princess uses the control setup first employed in which previous game?
# question_text = What is Clawshot's main weapon?
# question_text = What secondary weapon in Clawshot Princess is analogous to a weapon featured in previous games?
# question_text = What genre of games is Clawshot Princess?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = The context-sensitive button mechanic allows one button to serve a variety of functions, such as talking, opening doors, and pushing, pulling, and throwing objects.[e] The on-screen display shows what action, if any, the button will trigger, determined by the situation. For example, if Link is holding a rock, the context-sensitive button will cause Link to throw the rock if he is moving or targeting an object or enemy, or place the rock on the ground if he is standing still.[f]
#
# question_text = Many different types of interaction can be controlled by how many buttons?
# question_text = Where can players see what action will be performed in different scenarios?
# question_text = If Link is not moving, where will he put the projectile he's carrying?
# question_text = What mechanic allows one button to serve many functions?
# question_text = What shows what action the button will trigger?
# question_text = Many different types of interaction can be controlled by how many rocks?
# question_text = Where can players see what action will be performed in different rocks?
# question_text = If Link is not moving, where will he put the enemy he's carrying?
# question_text = What mechanic allows two buttons to serve many functions?
# question_text = What shows what action the rock will trigger?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = Spectre (2015) is the twenty-fourth James Bond film produced by Eon Productions. It features Daniel Craig in his fourth performance as James Bond, and Christoph Waltz as Ernst Stavro Blofeld, with the film marking the character's re-introduction into the series. It was directed by Sam Mendes as his second James Bond film following Skyfall, and was written by John Logan, Neal Purvis, Robert Wade and Jez Butterworth. It is distributed by Metro-Goldwyn-Mayer and Columbia Pictures. With a budget around $245 million, it is the most expensive Bond film and one of the most expensive films ever made.
#
# question_text = Which company made Spectre?
# question_text = Who is the star of Spectre?
# question_text = What role does Daniel Craig play in Spectre?
# question_text = What 007 movie did Sam Mendes previously direct?
# question_text = How much money did it take to make Spectre?
# question_text = How many James Bond films has Eon Productions produced?
# question_text = Which Bond film was the most expensive ever made?
# question_text = How many films has Daniel Craig appeared in as James Bond?
# question_text = Which two movie studios distributed the James Bond film Spectre?
# question_text = Who directed Spectre?
# question_text = What is the name of the thirty-fourth James Bond film?
# question_text = In what year was the thirty-fourth James Bond film produced?
# question_text = Daniel Craig stars as Ernst Stavro Blofeld in what 2015 film?
# question_text = Sam Mendes wrote what 2015 film?
# question_text = John Logan directed what 2015 film?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = The story sees Bond pitted against the global criminal organisation Spectre, marking the group's first appearance in an Eon Productions film since 1971's Diamonds Are Forever,[N 2] and tying Craig's series of films together with an overarching storyline. Several recurring James Bond characters, including M, Q and Eve Moneypenny return, with the new additions of Léa Seydoux as Dr. Madeleine Swann, Dave Bautista as Mr. Hinx, Andrew Scott as Max Denbigh and Monica Bellucci as Lucia Sciarra.
#
# question_text = What group is the enemy of the protagonist?
# question_text = Which movie was Spectre originally featured in?
# question_text = Which three personalities from previous films appear in Spectre?
# question_text = Which actor plays the role of Mr. Hinx?
# question_text = What role is performed by Monica Bellucci?
# question_text = Which recurring James Bond characters appear in Spectre?
# question_text = What actress portrays Dr. Madeleine Swann in Spectre?
# question_text = What actor portrays Mr. Hinx in Spectre?
# question_text = When was Diamonds are Forever released?
# question_text = Spectre is pitted against which global crime organization?
# question_text = Diamonds Aren't Forever was released in what year?
# question_text = M, Q, and Eva Moneypenny return in what 2015 film?
# question_text = Dave Bautista portrays Max Denbigh in which James Bond film?
# question_text = Andrew Scott portrays Mr. Hinx in which James Bond film?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = Spectre was released on 26 October 2015 in the United Kingdom on the same night as the world premiere at the Royal Albert Hall in London, followed by a worldwide release. It was released in the United States on 6 November 2015. It became the second James Bond film to be screened in IMAX venues after Skyfall, although it was not filmed with IMAX cameras. Spectre received mixed reviews upon its release; although criticised for its length, lack of screen time for new characters, and writing, it received praise for its action sequences and cinematography. The theme song, "Writing's on the Wall", received mixed reviews, particularly compared to the previous theme; nevertheless, it won the Golden Globe for Best Original Song and was nominated for the Academy Award in the same category. As of 20 February 2016[update], Spectre has grossed over $879 million worldwide.
#
# question_text = On what date was Spectre first shown in the UK?
# question_text = Where was the first screening of Spectre?
# question_text = What was the US release date for Spectre?
# question_text = What were two subjects of accolades for Spectre?
# question_text = For what category did Spectre receive a Golden Globe award?
# question_text = What was the first James Bond film to be screened at IMAX theaters?
# question_text = What was the theme song for the James Bond film Spectre?
# question_text = What James Bond movie was released on 16 October 2015?
# question_text = What James Bond movie was released on 26 October 2015 in the US?
# question_text = Which 2015 James Bond film received overwhelmingly positive reviews?
# question_text = Spectre won an Academy Award in which category?
# question_text = What James Bond movie was released on 6 November 2015 in the UK?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = Following Garreth Mallory's promotion to M, on a mission in Mexico City unofficially ordered by a posthumous message from the previous M, 007 James Bond kills three men plotting a terrorist bombing during the Day of the Dead and gives chase to Marco Sciarra, an assassin who survived the attack. In the ensuing struggle, Bond steals his ring, which is emblazoned with a stylised octopus, and then kills Sciarra by kicking him out of a helicopter. Upon returning to London, Bond is indefinitely suspended from field duty by M, who is in the midst of a power struggle with C, the head of the privately-backed Joint Intelligence Service, consisting of the recently merged MI5 and MI6. C campaigns for Britain to form alongside 8 other countries "Nine Eyes ", a global surveillance and intelligence co-operation initiative between nine member states, and uses his influence to close down the '00' section, believing it to be outdated.
#
# question_text = On what holiday do insurgents plan to detonate a bomb?
# question_text = Who removed James Bond from active service?
# question_text = Who is M's rival?
# question_text = What group does C support England joining?
# question_text = Which character is promoted to M?
# question_text = Which holiday was the terrorist bombing planned for?
# question_text = Which two intelligence groups merged to form Joint Intelligence Service?
# question_text = What does Bond take from Marco Sciarra?
# question_text = 007 James Bond kills four men in a mission in which city?
# question_text = Bond steals which assassin's necklace?
# question_text = Marco Scciarra's necklace has what animal on it?
# question_text = Q suspends whom from field duty?
# question_text = What consists of the recently merged MI55 and MI66?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = Bond disobeys M's order and travels to Rome to attend Sciarra's funeral. That evening he visits Sciarra's widow Lucia, who tells him about Spectre, a criminal organisation to which her husband belonged. Bond infiltrates a Spectre meeting, where he identifies the leader, Franz Oberhauser. When Oberhauser addresses Bond by name, he escapes and is pursued by Mr. Hinx, a Spectre assassin. Moneypenny informs Bond that the information he collected leads to Mr. White, former member of Quantum, a subsidiary of Spectre. Bond asks her to investigate Oberhauser, who was presumed dead years earlier.
#
# question_text = Where does Bond go after his suspension?
# question_text = What group did Sciarra belong to?
# question_text = Who is the head of Spectre?
# question_text = What is Mr. Hinx's job?
# question_text = Who performs research for Bond?
# question_text = Where does Sciarra's funeral take place?
# question_text = Who is the leader of Spectre?
# question_text = What is the name of the Spectre assassin who tracks Bond?
# question_text = Which member of Spectre had been presumed to be dead?
# question_text = Who disobeys Q's orders and travels to Rome?
# question_text = Whose wife belonged to a criminal organization?
# question_text = Who is pursued by Mr. Oberhauser, a Spectre assasin?
# question_text = Who is a current member of Quantum?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = The 2008 Sichuan earthquake or the Great Sichuan earthquake, measured at 8.0 Ms and 7.9 Mw, and occurred at 02:28:01 PM China Standard Time at epicenter (06:28:01 UTC) on May 12 in Sichuan province, killed 69,197 people and left 18,222 missing.
#
# question_text = In what year did the earthquake in Sichuan occur?
# question_text = What was the earthquake named?
# question_text = How many people were killed as a result?
# question_text = What year did the Sichuan earthquake take place?
# question_text = What did the quake measure?
# question_text = What day did the earthquake occur?
# question_text = What time of the day did the quake happen?
# question_text = How many people died?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = It is also known as the Wenchuan earthquake (Chinese: 汶川大地震; pinyin: Wènchuān dà dìzhèn; literally: "Great Wenchuan earthquake"), after the location of the earthquake's epicenter, Wenchuan County, Sichuan. The epicenter was 80 kilometres (50 mi) west-northwest of Chengdu, the provincial capital, with a focal depth of 19 km (12 mi). The earthquake was also felt in nearby countries and as far away as both Beijing and Shanghai—1,500 km (930 mi) and 1,700 km (1,060 mi) away—where office buildings swayed with the tremor. Strong aftershocks, some exceeding magnitude 6, continued to hit the area even months after the main quake, causing new casualties and damage.
#
# question_text = Which far away cities in other countries could feel the earthquake?
# question_text = What was the focal depth of the earthquake?
# question_text = How long after the earthquake were aftershocks felt?
# question_text = What is another name for the earthquake in Sichuan?
# question_text = Where was the epicenter of the earthquake?
# question_text = How far was it from Chengdu?
# question_text = What was the focal depth of the quake?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = Official figures (as of July 21, 2008 12:00 CST) stated that 69,197 were confirmed dead, including 68,636 in Sichuan province, and 374,176 injured, with 18,222 listed as missing. The earthquake left about 4.8 million people homeless, though the number could be as high as 11 million. Approximately 15 million people lived in the affected area. It was the deadliest earthquake to hit China since the 1976 Tangshan earthquake, which killed at least 240,000 people, and the strongest in the country since the 1950 Chayu earthquake, which registered at 8.5 on the Richter magnitude scale. It is the 21st deadliest earthquake of all time. On November 6, 2008, the central government announced that it would spend 1 trillion RMB (about US $146.5 billion) over the next three years to rebuild areas ravaged by the earthquake, as part of the Chinese economic stimulus program.
#
# question_text = How many people were confirmed dead?
# question_text = How many people were confirmed dead only in the Sichuan province?
# question_text = How many people were left homeless because of the earthquake?
# question_text = How many people lived in the affected area?
# question_text = How much money was dedicated to rebuild ravaged areas?
# question_text = How many people died in Sichuan Province?
# question_text = How many were injured in Sichuan?
# question_text = How many people are listed as missing?
# question_text = How many people are homeless because of the quake?
# question_text = How high could the homeless number possibly go?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = The earthquake had a magnitude of 8.0 Ms and 7.9 Mw. The epicenter was in Wenchuan County, Ngawa Tibetan and Qiang Autonomous Prefecture, 80 km west/northwest of the provincial capital of Chengdu, with its main tremor occurring at 14:28:01.42 China Standard Time (06:28:01.42 UTC), on May 12, 2008 lasting for around 2 minutes, in the quake almost 80% of buildings were destroyed.
#
# question_text = Where was the epicenter?
# question_text = How long did the earthquake last?
# question_text = What percentage of buildings were destroyed?
# question_text = What was the magnitude of the earthquake?
# question_text = How long did the main tremor last?
# ...
# question_text = What were Rome's legislative structures eventually turned into?
# question_text = What was the senate that advised consuls in the Roman government comprised of?
# question_text = What went hand and hand with military success?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = The exact causes and motivations for Rome's military conflicts and expansions during the republic are subject to wide debate. While they can be seen as motivated by outright aggression and imperialism, historians typically take a much more nuanced view. They argue that Rome's expansion was driven by short-term defensive and inter-state factors (that is, relations with city-states and kingdoms outside Rome's hegemony), and the new contingencies that these decisions created. In its early history, as Rome successfully defended itself against foreign threats in central and then northern Italy, neighboring city-states sought the protection a Roman alliance would bring. As such, early republican Rome was not an "empire" or "state" in the modern sense, but an alliance of independent city-states (similar to the Greek hegemonies of the same period) with varying degrees of genuine independence (which itself changed over time) engaged in an alliance of mutual self-protection, but led by Rome. With some important exceptions, successful wars in early republican Rome generally led not to annexation or military occupation, but to the restoration of the way things were. But the defeated city would be weakened (sometimes with outright land concessions) and thus less able to resist Romanizing influences, such as Roman settlers seeking land or trade with the growing Roman confederacy. It was also less able to defend itself against its non-Roman enemies, which made attack by these enemies more likely. It was, therefore, more likely to seek an alliance of protection with Rome.
#
# question_text = What factor is considered by some to be the main driving force behind the expansion of Rome?
# question_text = What type of policy is considered by some to be responsible for Rome's many military conflicts?
# question_text = What was a common conclusion to wars in the early days of republican Rome?
# question_text = What type of alliance was created between the various Roman city-states?
# question_text = What did Roman settlers commonly seek out?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = This growing coalition expanded the potential enemies that Rome might face, and moved Rome closer to confrontation with major powers. The result was more alliance-seeking, on the part of both the Roman confederacy and city-states seeking membership (and protection) within that confederacy. While there were exceptions to this (such as military rule of Sicily after the First Punic War), it was not until after the Second Punic War that these alliances started to harden into something more like an empire, at least in certain locations. This shift mainly took place in parts of the west, such as the southern Italian towns that sided with Hannibal.
#
# question_text = After what war did the alliances start to solidify?
# question_text = What helped Rome move closer to a confrontation with several other major powers in the area?
# question_text = What towns had chosen Hannibal's side?
# question_text = What did city-states hope to gain from the Roman confederacy?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = In contrast, Roman expansion into Spain and Gaul occurred as a mix of alliance-seeking and military occupation. In the 2nd century BC, Roman involvement in the Greek east remained a matter of alliance-seeking, but this time in the face of major powers that could rival Rome. According to Polybius, who sought to trace how Rome came to dominate the Greek east in less than a century, this was mainly a matter of several Greek city-states seeking Roman protection against the Macedonian kingdom and Seleucid Empire in the face of destabilisation created by the weakening of Ptolemaic Egypt. In contrast to the west, the Greek east had been dominated by major empires for centuries, and Roman influence and alliance-seeking led to wars with these empires that further weakened them and therefore created an unstable power vacuum that only Rome could fill. This had some important similarities to (and important differences from) the events in Italy centuries earlier, but this time on a global scale.
#
# question_text = What effect did the weakening of Ptolemaic Egypt have on nearby areas?
# question_text = Who attempted to find out how Rome dominated the Greek east?
# question_text = Why was Rome involved in matters in the Greek east?
# question_text = Which countries citie-states attempted to gain the protection of Rome?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = It is generally considered that the Pacific War began on 7/8 December 1941, on which date Japan invaded Thailand and attacked the British possessions of Malaya, Singapore, and Hong Kong as well as the United States military bases in Hawaii, Wake Island, Guam and the Philippines. Some historians contend that the conflict in Asia can be dated back to 7 July 1937 with the beginning of the Second Sino-Japanese War between the Empire of Japan and the Republic of China, or possibly 19 September 1931, beginning with the Japanese invasion of Manchuria. However, it is more widely accepted that the Pacific War itself started in early December 1941, with the Sino-Japanese War then becoming part of it as a theater of the greater World War II.[nb 9]
#
# question_text = When do most people believe the Pacific War began?
# question_text = On what date did Japan attack Pearl Harbor?
# question_text = When did the Second Sino-Japanese War begin?
# question_text = Which countries did the Second Sino-Japanese War encompass?
# question_text = Has Japan ever attacked Thailand?
# question_text = What is the generally accepted date the Pacific War started?
# question_text = When did Japan invade Manchuria?
# question_text = What nation initiated hostilities?
# question_text = What was the Pacific War theater part of after December 1941?
# question_text = When did Japan invade China?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = The Pacific War saw the Allied powers pitted against the Empire of Japan, the latter briefly aided by Thailand and to a much lesser extent by its Axis allies, Germany and Italy. The war culminated in the atomic bombings of Hiroshima and Nagasaki, and other large aerial bomb attacks by the United States Army Air Forces, accompanied by the Soviet invasion of Manchuria on 8 August 1945, resulting in the Japanese announcement of intent to surrender on 15 August 1945. The formal and official surrender of Japan took place aboard the battleship USS Missouri in Tokyo Bay on 2 September 1945. Following its defeat, Japan's Shinto Emperor stepped down as the divine leader through the Shinto Directive, because the Allied Powers believed this was the major political cause of Japan's military aggression and deconstruction process soon took place to install a new liberal-democratic constitution to the Japanese public as the current Constitution of Japan.
#
# question_text = What events ended the war with Japan?
# question_text = On what date did Japan surrender?
# question_text = Where did Japan's surrender occur?
# question_text = What changed in the ruling of Japan after the war?
# question_text = What was the process called whereby the leader of Japan stepped down?
# question_text = What nation were the allies against?
# question_text = What nations comprised the Axis?
# question_text = What cities were destroyed by atom bombs?
# question_text = When did the Soviet Union invade Manchuria?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = Japan used the name Greater East Asia War (大東亜戦争, Dai Tō-A Sensō?), as chosen by a cabinet decision on 10 December 1941, to refer to both the war with the Western Allies and the ongoing war in China. This name was released to the public on 12 December, with an explanation that it involved Asian nations achieving their independence from the Western powers through armed forces of the Greater East Asia Co-Prosperity Sphere. Japanese officials integrated what they called the Japan–China Incident (日支事変, Nisshi Jihen?) into the Greater East Asia War.
#
# question_text = By what name was the war with Japan referred?
# question_text = What did Japanese officials call the war?
# question_text = What was the reason Japan gave for the war?
# question_text = What date was the new name of the war released?
# question_text = What name did Japan call the war?
# question_text = When did Japan adobt the name for the war?
# question_text = What was Japan's publicised war goal?
# question_text = What did Japan call the occupied group of Asian nations?
# question_text = How was the name of the war chosen by Japan?
# **********
# *** Paragraph 4 ***
#
# paragraph_text = The Axis states which assisted Japan included the authoritarian government of Thailand in World War II, which quickly formed a temporary alliance with the Japanese in 1941, as the Japanese forces were already invading the peninsula of southern Thailand. The Phayap Army sent troops to invade and occupy northeastern Burma, which was former Thai territory that had been annexed by Britain much earlier. Also involved were the Japanese puppet states of Manchukuo and Mengjiang (consisting of most of Manchuria and parts of Inner Mongolia respectively), and the collaborationist Wang Jingwei regime (which controlled the coastal regions of China).
#
# question_text = What role did Thailand play in the war?
# question_text = Which group controlled Chinese costal regions?
# question_text = Which army invaded Burma?
# question_text = Burma was formerly annexed by what country?
# question_text = What states assisting Japan was Thailand a part of?
# question_text = What year did Thailand form an alliance with Japan?
# question_text = What army invaded northeastern Burma?
# question_text = What were the Japanese puppet states?
# question_text = Who controlled the coast of China?
# **********
# *** Paragraph 5 ***
#
# paragraph_text = The official policy of the U.S. Government is that Thailand was not an ally of the Axis, and that the United States was not at war with Thailand. The policy of the U.S. Government ever since 1945 has been to treat Thailand not as a former enemy, but rather as a country which had been forced into certain actions by Japanese blackmail, before being occupied by Japanese troops. Thailand has been treated by the United States in the same way as such other Axis-occupied countries as Belgium, Czechoslovakia, Denmark, Greece, Norway, Poland, and the Netherlands.
#
# question_text = Did the U.S. believe that Thailand was an Axis ally?
# question_text = What does the U.S. believe caused Thailand to help Japan?
# question_text = Is Thailand treated differently than other Axis countries?
# question_text = According to the USA, what country did Japan blackmail?
# question_text = What nations were occupied by the Axis?
# question_text = After 1945, how did the USA treat Thailand?
# question_text = Who occupied Thailand according to the USA?
# **********
# *** Paragraph 1 ***
#
# paragraph_text = With an estimated population of 1,381,069 as of July 1, 2014, San Diego is the eighth-largest city in the United States and second-largest in California. It is part of the San Diego–Tijuana conurbation, the second-largest transborder agglomeration between the US and a bordering country after Detroit–Windsor, with a population of 4,922,723 people. San Diego is the birthplace of California and is known for its mild year-round climate, natural deep-water harbor, extensive beaches, long association with the United States Navy and recent emergence as a healthcare and biotechnology development center.
#
# question_text = Which city in Mexico does San Diego border?
# question_text = Of all military branches, which one has the strongest presence in San Diego?
# question_text = Aside from healthcare, which employment sector has strongly emerged in San Diego?
# question_text = Of the top 10 largest cities in the country, which place does San Diego rank?
# question_text = What is unique about San Diego's harbors?
# question_text = Which city in Mexico doesn't San Diego border?
# question_text = Of all military branches, which one has the weakest presence in San Diego?
# question_text = Aside from healthcare, which employment sector has weakly emerged in San Diego?
# question_text = Of the top 5 largest cities in the country, which place does San Diego rank?
# question_text = What isn't unique about San Diego's harbors?
# **********
# *** Paragraph 2 ***
#
# paragraph_text = Historically home to the Kumeyaay people, San Diego was the first site visited by Europeans on what is now the West Coast of the United States. Upon landing in San Diego Bay in 1542, Juan Rodríguez Cabrillo claimed the entire area for Spain, forming the basis for the settlement of Alta California 200 years later. The Presidio and Mission San Diego de Alcalá, founded in 1769, formed the first European settlement in what is now California. In 1821, San Diego became part of the newly-independent Mexico, which reformed as the First Mexican Republic two years later. In 1850, it became part of the United States following the Mexican–American War and the admission of California to the union.
#
# question_text = Who claimed the San Diego Bay area for Spain in 1542?
# question_text = In what year did San Diego become part of the United States?
# question_text = What native people lived in the San Diego area before the Europeans arrived?
# question_text = After the land was claimed for Spain, how many years passed before the settlement of Alta began?
# question_text = Who claimed the San Diego Bay area for Spain in 1524?
# question_text = In what year didn't San Diego become part of the United States?
# question_text = What native people never lived in the San Diego area before the Europeans arrived?
# question_text = What native people lived in the San Diego area before the Mexicans arrived?
# question_text = After the land was claimed for Spain, how many years passed before the settlement of Atlanta began?
# **********
# *** Paragraph 3 ***
#
# paragraph_text = The first European to visit the region was Portuguese-born explorer Juan Rodríguez Cabrillo sailing under the flag of Castile. Sailing his flagship San Salvador from Navidad, New Spain, Cabrillo claimed the bay for the Spanish Empire in 1542, and named the site 'San Miguel'. In November 1602, Sebastián Vizcaíno was sent to map the California coast. Arriving on his flagship San Diego, Vizcaíno surveyed the harbor and what are now Mission Bay and Point Loma and named the area for the Catholic Saint Didacus, a Spaniard more commonly known as San Diego de Alcalá. On November 12, 1602, the first Christian religious service of record in Alta California was conducted by Friar Antonio de la Ascensión, a member of Vizcaíno's expedition, to celebrate the feast day of San Diego.
#
# question_text = Who was sent to survey the California coast in 1602?
# question_text = What was the name of Juan Rodriguez Cabrillo's ship?
# question_text = Who was the harbor named for?
# question_text = Who conducted the first Christian service to be recorded in Alta?
# question_text = Where did Cabrillo leave from to embark on his journey to the West Coast?
# question_text = Who was sent to survey the California coast in 1620?
# question_text = What was the name of Juan Rodriguez Cabrillo's car?
# question_text = Who wasn't the harbor named for?
# question_text = Who conducted the last Christian service to be recorded in Alta?
# question_text = Where did Cabrillo leave from to embark on his journey to the East Coast?
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
